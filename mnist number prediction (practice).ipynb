# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
#from keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import Adam, SGD

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model

# %%
network = tf.keras.Sequential()
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
#network.add(layers.Dense(20))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=512)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 231us/sample - loss: 0.3836 - accuracy: 0.8878
# Epoch 2/5
# 60000/60000 [==============================] - 14s 236us/sample - loss: 0.1579 - accuracy: 0.9541
# Epoch 3/5
# 60000/60000 [==============================] - 14s 238us/sample - loss: 0.1050 - accuracy: 0.9689
# Epoch 4/5
# 60000/60000 [==============================] - 13s 215us/sample - loss: 0.0763 - accuracy: 0.9777
# Epoch 5/5
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.0578 - accuracy: 0.9825

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc: 0.9629

# %%
# %matplotlib inline

# %%
plt.plot(train_labels, train_images)
plt.show()
# Out:
# /home/khizram/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: cycling among columns of inputs with non-matching shapes is deprecated.
#   """Entry point for launching an IPython kernel.
